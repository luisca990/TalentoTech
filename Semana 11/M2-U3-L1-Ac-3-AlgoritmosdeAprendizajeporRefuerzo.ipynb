# %%
class Environment:
    def __init__(self):
        self.state_space = [0, 1, 2, 3]
        self.action_space = [0, 1]
        self.rewards={0:-1,1:-1,2:-1,3:10}

env=Environment()
print(env.state_space)
print(env.action_space)
print(env.rewards)
# Out:
# [0, 1, 2, 3]
# [0, 1]
# {0: -1, 1: -1, 2: -1, 3: 10}

# %%
import numpy as np

Q=np.zeros((len(env.state_space),len(env.action_space)))
alpha=0.1
gamma=0.9

for _ in range(100):
  state=np.random.choice(env.state_space)

  while state!=3:
    action=np.random.choice(env.action_space)
    next_state=state+action
    reward=env.rewards[next_state]
    Q[state,action]=Q[state,action]+alpha*(reward+gamma*np.max(Q[next_state])-Q[state,action])
    state=next_state

print(Q)
# Out:
# [[1.03410031 4.37169351]
#  [4.40946223 7.7356141 ]
#  [7.88156389 9.98938883]
#  [0.         0.        ]]

# %% [markdown]
# # 3. Sarsa:

# %%
Q=np.zeros((len(env.state_space),len(env.action_space)))

for _ in range(100):
  state=np.random.choice(env.state_space)
  action=np.random.choice(env.action_space)
  while state!=3:
    next_state=state+action
    next_action=np.random.choice(env.action_space)
    reward=env.rewards[next_state]
    Q[state,action]=Q[state,action]+alpha*(reward+gamma*Q[next_state,next_action]-Q[state,action])
    state=next_state
    action=next_action

print(Q)
# Out:
# [[-1.23062756  1.52443044]
#  [ 2.33450336  6.39987767]
#  [ 6.93716231  9.99840732]
#  [ 0.          0.        ]]

# %% [markdown]
# # 4. Política de Gradiente de Montecarlo:

# %%
policy=np.ones((len(env.state_space),len(env.action_space)))/len(env.action_space)

# %%
def average_reward(Q):
  return np.mean([Q[state,np.argmax(policy[state])] for state in env.state_space])

for _ in range(100):
  state=np.random.choice(env.state_space)
  while state!=3:
    action=np.random.choice(env.action_space,p=policy[state])
    next_state=state+action
    reward=env.rewards[next_state]
    gradient=np.zeros_like(policy[state])
    gradient[action]=1
    policy[state]+=alpha*gradient*(reward-average_reward(Q))
    state=next_state

print(policy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-200d98d88695> in <cell line: 4>()
#       5   state=np.random.choice(env.state_space)
#       6   while state!=3:
# ----> 7     action=np.random.choice(env.action_space,p=policy[state])
#       8     next_state=state+action
#       9     reward=env.rewards[next_state]
#
# numpy/random/mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities do not sum to 1
