# %% [markdown]
# # Importar librerias

# %%
import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.datasets import make_classification

# %% [markdown]
# # Generación de datos de clasificación sintéticos

# %%
X,y= make_classification(n_samples=100,n_features=5,n_classes=2)

# %% [markdown]
# # División de los datos

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %% [markdown]
# # Codificación one-hot de las etiquetas

# %%
y_train_cat=keras.utils.to_categorical(y_train)
y_test_cat=keras.utils.to_categorical(y_test)

# %% [markdown]
# # Creación del modelo

# %%
model=keras.Sequential()
model.add(keras.layers.Dense(10, input_shape=(X_train.shape[1],), activation='relu'))
model.add(keras.layers.Dense(2, activation='softmax'))

# %% [markdown]
# # Compilación del modelo

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Entrenamiento del modelo

# %%
model.fit(X_train, y_train_cat, epochs=100, batch_size=10, validation_data=(X_test, y_test_cat))
# Out:
# Epoch 1/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6338 - accuracy: 0.5625 - val_loss: 0.8025 - val_accuracy: 0.5000
# Epoch 2/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6227 - accuracy: 0.5750 - val_loss: 0.7905 - val_accuracy: 0.5000
# Epoch 3/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6121 - accuracy: 0.6000 - val_loss: 0.7778 - val_accuracy: 0.5000
# Epoch 4/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6022 - accuracy: 0.6125 - val_loss: 0.7672 - val_accuracy: 0.5000
# Epoch 5/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5923 - accuracy: 0.6125 - val_loss: 0.7588 - val_accuracy: 0.5000
# Epoch 6/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5824 - accuracy: 0.6500 - val_loss: 0.7538 - val_accuracy: 0.5500
# Epoch 7/100
# ...

# %% [markdown]
# # Evaluación del modelo

# %%
loss, accuracy = model.evaluate(X_test, y_test_cat)
print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5597 - accuracy: 0.7000
# Loss: 0.5597293972969055
# Accuracy: 0.699999988079071

# %%
matrix=confusion_matrix(y_test,model.predict(X_test).argmax(axis=1))
print(matrix)
# Out:
# 1/1 [==============================] - 0s 160ms/step
# [[6 0]
#  [6 8]]

# %%
report=classification_report(y_test,model.predict(X_test).argmax(axis=1))
print(report)
# Out:
# 1/1 [==============================] - 0s 98ms/step
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         6
#            1       1.00      0.57      0.73        14
#
#     accuracy                           0.70        20
#    macro avg       0.75      0.79      0.70        20
# weighted avg       0.85      0.70      0.71        20
